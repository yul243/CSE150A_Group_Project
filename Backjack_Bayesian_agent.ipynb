# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("dennisho/blackjack-hands")

# print("Path to dataset files:", path)

import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.model_selection import train_test_split
import ast

# %%
# Load the dataset (replace with your actual file path)
data = pd.read_csv("blackjack_simulator.csv")  # Replace 'your_data.csv' with the actual filename
data
# Out:
#           shoe_id  cards_remaining  dealer_up initial_hand  dealer_final  \
# 0               0              416         10     [10, 11]   [10, 4, 10]
# 1               0              411         10       [5, 5]       [10, 8]
# 2               0              406          6      [3, 10]    [6, 6, 10]
# 3               0              401         10       [5, 9]       [10, 8]
# 4               0              395          8      [6, 10]    [8, 2, 10]
# ...           ...              ...        ...          ...           ...
# 49999995   822844              108         10       [7, 9]   [10, 3, 10]
# 49999996   822844              103          5       [9, 9]  [5, 2, 5, 9]
# 49999997   822844               95         10     [10, 10]      [10, 10]
# 49999998   822844               91          9      [4, 10]       [9, 10]
# 49999999   822844               86         10      [10, 8]      [10, 10]
#
#          dealer_final_value        player_final player_final_value  \
# 0                        24          [[10, 11]]             ['BJ']
# 1                        18        [[5, 5, 11]]               [21]
# 2                        22           [[3, 10]]               [13]
# 3                        18     [[5, 9, 11, 3]]               [18]
# 4                        20       [[6, 10, 10]]               [26]
# ...                     ...                 ...                ...
# 49999995                 23            [[7, 9]]               [16]
# 49999996                 21  [[9, 10], [9, 10]]           [19, 19]
# 49999997                 20          [[10, 10]]               [20]
# 49999998                 19        [[4, 10, 9]]               [23]
# 49999999                 20           [[10, 8]]               [18]
#
#                 actions_taken  run_count  true_count  win
# 0                     [['S']]          1           0  1.5
# 1                [['H', 'S']]         -2           0  1.0
# 2                     [['S']]         -2           0  1.0
# 3           [['H', 'H', 'S']]         -1           0  0.0
# 4                     [['H']]         -1           0 -1.0
# ...                       ...        ...         ...  ...
# 49999995              [['R']]         14           6 -0.5
# 49999996  [['P', 'S'], ['S']]         13           6 -2.0
# 49999997              [['S']]         14           7  0.0
# 49999998              [['H']]         10           5 -1.0
# 49999999              [['S']]          9           5 -1.0
#
# [50000000 rows x 12 columns]

# %%
data.dtypes
# Out:
# shoe_id                 int64
# cards_remaining         int64
# dealer_up               int64
# initial_hand           object
# dealer_final           object
# dealer_final_value     object
# player_final           object
# player_final_value     object
# actions_taken          object
# run_count               int64
# true_count              int64
# win                   float64
# dtype: object

# %%
# --- Data Preprocessing ---

# Keep all columns
df = data.copy()

# Convert 'win' to categorical: win, lose, push
df['win'] = df['win'].apply(lambda x: 'win' if x > 0 else ('lose' if x < 0 else 'push'))

# Convert all object columns to strings (important for Bayesian Network).
for col in df.select_dtypes(include='object'):
    df[col] = df[col].astype(str)

# For simplicity, convert numerical columns into categorical columns with bins
for col in df.select_dtypes(include=np.number):
    df[col] = pd.cut(df[col], bins=5, labels=False, include_lowest=True) # Convert to categorical

# Drop any remaining NaN - can cause issues with CPT calculation
df.dropna(inplace=True)

# %%
df
# Out:
#           shoe_id  cards_remaining  dealer_up initial_hand  dealer_final  \
# 0               0                4          4     [10, 11]   [10, 4, 10]
# 1               0                4          4       [5, 5]       [10, 8]
# 2               0                4          2      [3, 10]    [6, 6, 10]
# 3               0                4          4       [5, 9]       [10, 8]
# 4               0                4          3      [6, 10]    [8, 2, 10]
# ...           ...              ...        ...          ...           ...
# 49999995        4                0          4       [7, 9]   [10, 3, 10]
# 49999996        4                0          1       [9, 9]  [5, 2, 5, 9]
# 49999997        4                0          4     [10, 10]      [10, 10]
# 49999998        4                0          3      [4, 10]       [9, 10]
# 49999999        4                0          4      [10, 8]      [10, 10]
#
#          dealer_final_value        player_final player_final_value  \
# 0                        24          [[10, 11]]             ['BJ']
# 1                        18        [[5, 5, 11]]               [21]
# 2                        22           [[3, 10]]               [13]
# 3                        18     [[5, 9, 11, 3]]               [18]
# 4                        20       [[6, 10, 10]]               [26]
# ...                     ...                 ...                ...
# 49999995                 23            [[7, 9]]               [16]
# 49999996                 21  [[9, 10], [9, 10]]           [19, 19]
# 49999997                 20          [[10, 10]]               [20]
# 49999998                 19        [[4, 10, 9]]               [23]
# 49999999                 20           [[10, 8]]               [18]
#
#                 actions_taken  run_count  true_count   win
# 0                     [['S']]          2           2   win
# 1                [['H', 'S']]          2           2   win
# 2                     [['S']]          2           2   win
# 3           [['H', 'H', 'S']]          2           2  push
# 4                     [['H']]          2           2  lose
# ...                       ...        ...         ...   ...
# 49999995              [['R']]          3           3  lose
# 49999996  [['P', 'S'], ['S']]          3           3  lose
# 49999997              [['S']]          3           3  push
# 49999998              [['H']]          3           3  lose
# 49999999              [['S']]          2           3  lose
#
# [50000000 rows x 12 columns]

# %%
# --- Split into Training and Testing Sets ---
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)  # 80% train, 20% test

# %%
# --- Build Bayesian Network (From Scratch) ---

class BayesianNode:
    def __init__(self, name, parents=None):
        self.name = name
        self.parents = parents if parents else []
        self.cpt = {}  # Conditional Probability Table

    def compute_cpt(self, data):
        """Computes the CPT based on the data."""
        if not self.parents:
            # If no parents, calculate marginal probabilities
            counts = data[self.name].value_counts(normalize=True)
            self.cpt = counts.to_dict()
        else:
            # Calculate conditional probabilities
            grouped = data.groupby([parent.name for parent in self.parents] + [self.name])
            total_counts = data.groupby([parent.name for parent in self.parents]).size().to_dict()
            counts = grouped.size().to_dict()

            for cond, count in counts.items():
                condition = cond[:-1]
                outcome = cond[-1]

                if isinstance(condition, str):
                    condition = (condition,)

                condition_key = condition
                if len(condition) == 1:
                    condition_key = condition[0]
                elif len(condition) > 1:
                    condition_key = tuple(condition)

                if condition_key not in self.cpt:
                    self.cpt[condition_key] = {}

                # Safe check
                if condition_key not in total_counts:
                    print(f"Warning: Condition {condition_key} not found in total counts for node{self.name} with condition {condition_key}")
                    self.cpt[condition_key] = {}  # empty dictionary
                else:
                    self.cpt[condition_key][outcome] = count / total_counts[condition_key]

    def predict_proba(self, evidence):
        """Predicts probabilities given evidence."""
        if not self.parents:
            return self.cpt  # Return marginal probabilities

        # Find relevant condition based on evidence
        condition = tuple(evidence[parent.name] for parent in self.parents)

        if condition in self.cpt:
            return self.cpt[condition]
        else:
            # Handle unseen conditions (e.g., return a uniform distribution)
            print(f"Warning: Condition {condition} not found in CPT for node {self.name}. Returning uniform distribution.")
            outcomes = train_df[self.name].unique()  # Important - uses train_df
            return {outcome: 1.0 / len(outcomes) for outcome in outcomes}

# --- Build the Network Structure (Define Dependencies) ---

# Create all nodes
nodes = {col: BayesianNode(col) for col in df.columns}

# Define a simple structure: Make each column a parent of 'win'
for col in df.columns:
    if col != 'win':
        nodes['win'].parents.append(nodes[col])

# --- Compute CPTs (Train on Training Data) ---
for node in nodes.values():
    node.compute_cpt(train_df)  # Compute CPTs using ONLY training data

# --- Inference Function ---
def predict_win_probability(evidence):
    """Predicts the probability of winning given evidence."""
    win_probs = nodes['win'].predict_proba(evidence)
    return win_probs

# %%
# --- Evaluation ---
def evaluate_model(test_df):
    """Evaluates the model on the test data."""
    correct_predictions = 0
    total_predictions = len(test_df)

    for index, row in test_df.iterrows():
        # Prepare evidence from the test data row
        evidence = row.drop('win').to_dict()  # All columns except 'win'

        # Convert types to string
        evidence = {str(k): str(v) for k, v in evidence.items()}

        # Make prediction
        probabilities = predict_win_probability(evidence)

        # Determine predicted win category (most probable)
        predicted_win = max(probabilities, key=probabilities.get)

        # Get actual win category from the test data
        actual_win = str(row['win'])  # Ensure it's a string

        # Compare prediction with actual
        if predicted_win == actual_win:
            correct_predictions += 1

    accuracy = correct_predictions / total_predictions
    return accuracy

# %%
# --- Example Usage and Evaluation ---

# Evaluate the model
accuracy = evaluate_model(test_df)
print(f"Accuracy on the test set: {accuracy:.4f}")
# Out:
# Warning: Condition ('2', '4', '2', '[5, 10]', '[6, 10, 10]', '26', '[[5, 10]]', '[15]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '1', '2', '[2, 11]', '[7, 5, 4, 10]', '26', '[[2, 11, 10, 8]]', '[21]', "[['H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '3', '[10, 5]', '[8, 7, 10]', '25', '[[10, 5, 10]]', '[25]', "[['H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '2', '[10, 3]', '[7, 10]', '17', '[[10, 3, 11, 7]]', '[21]', "[['H', 'H', 'S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '0', '0', '[4, 10]', '[2, 2, 8, 10]', '22', '[[4, 10]]', '[14]', "[['S']]", '1', '1') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '3', '2', '[3, 5]', '[6, 10, 7]', '23', '[[3, 5, 10]]', '[18]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '4', '3', '[9, 11]', '[9, 10]', '19', '[[9, 11]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '2', '4', '[7, 5]', '[10, 10]', '20', '[[7, 5, 11, 7]]', '[20]', "[['H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '3', '0', '[10, 3]', '[2, 2, 4, 3, 10]', '21', '[[10, 3]]', '[13]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '1', '2', '[10, 10]', '[6, 10, 10]', '26', '[[10, 10]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '4', '4', '[10, 10]', '[11, 4, 7, 3, 6]', '21', '[[10, 10]]', '[20]', "[['N', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '4', '4', '[10, 5]', '[10, 8]', '18', '[[10, 5]]', '[15]', "[['R']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '3', '3', '[10, 5]', '[9, 2, 9]', '20', '[[10, 5, 10]]', '[25]', "[['H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '0', '0', '[9, 10]', '[3, 10, 10]', '23', '[[9, 10]]', '[19]', "[['S']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '4', '2', '[2, 10]', '[6, 5, 4, 5]', '20', '[[2, 10]]', '[12]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '1', '4', '[6, 5]', '[10, 7]', '17', '[[6, 5, 9]]', '[20]', "[['D']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '1', '4', '[4, 5]', '[10, 4, 10]', '24', '[[4, 5, 8]]', '[17]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '2', '4', '[10, 6]', '[11, 5, 10, 10]', '26', '[[10, 6]]', '[16]', "[['N', 'R']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '4', '[3, 7]', '[10, 10]', '20', '[[3, 7, 3, 9]]', '[22]', "[['H', 'H']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '1', '4', '[10, 2]', '[10, 10]', '20', '[[10, 2, 10]]', '[22]', "[['H']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '4', '[9, 10]', '[10, 6, 2]', '18', '[[9, 10]]', '[19]', "[['S']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '0', '0', '[4, 4]', '[2, 10, 2, 4]', '18', '[[4, 4, 9]]', '[17]', "[['H', 'S']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '1', '4', '[10, 2]', '[10, 4, 3]', '17', '[[10, 2, 11, 6]]', '[19]', "[['H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '4', '[5, 7]', '[10, 9]', '19', '[[5, 7, 6]]', '[18]', "[['H', 'S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '4', '[3, 10]', '[10, 7]', '17', '[[3, 10, 10]]', '[23]', "[['H']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '4', '[3, 10]', '[10, 5, 5]', '20', '[[3, 10, 8]]', '[21]', "[['H', 'S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '0', '0', '[2, 10]', '[3, 3, 3, 2, 2, 2, 8]', '23', '[[2, 10, 10]]', '[22]', "[['H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '4', '[8, 7]', '[10, 11]', 'BJ', '[[8, 7]]', '[15]', '[[]]', '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '2', '2', '[10, 10]', '[7, 5, 10]', '22', '[[10, 10]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '2', '[4, 10]', '[7, 10]', '17', '[[4, 10, 10]]', '[24]', "[['H']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '3', '0', '[4, 11]', '[3, 10, 4]', '17', '[[4, 11, 5]]', '[20]', "[['H', 'S']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '1', '1', '[6, 4]', '[5, 2, 10]', '17', '[[6, 4, 9]]', '[19]', "[['D']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '4', '0', '[3, 11]', '[3, 5, 9]', '17', '[[3, 11, 10]]', '[14]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '3', '4', '[4, 2]', '[11, 10]', 'BJ', '[[4, 2]]', '[6]', "[['N']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '3', '4', '[5, 10]', '[10, 4, 5]', '19', '[[5, 10]]', '[15]', "[['R']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '0', '3', '[4, 6]', '[8, 10]', '18', '[[4, 6, 11]]', '[21]', "[['D']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '4', '0', '[10, 9]', '[2, 9, 8]', '19', '[[10, 9]]', '[19]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '4', '4', '[10, 10]', '[10, 8]', '18', '[[10, 10]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '3', '4', '[9, 10]', '[10, 9]', '19', '[[9, 10]]', '[19]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '1', '4', '[8, 10]', '[11, 10]', 'BJ', '[[8, 10]]', '[18]', "[['N']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '1', '4', '[8, 10]', '[10, 10]', '20', '[[8, 10]]', '[18]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '1', '0', '[8, 3]', '[2, 4, 10, 5]', '21', '[[8, 3, 5]]', '[16]', "[['D']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '4', '2', '[5, 9]', '[7, 10]', '17', '[[5, 9, 10]]', '[24]', "[['H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '0', '4', '[8, 6]', '[10, 10]', '20', '[[8, 6, 3]]', '[17]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '3', '4', '[4, 11]', '[10, 4, 8]', '22', '[[4, 11, 6]]', '[21]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '1', '2', '[7, 10]', '[6, 11, 11]', '18', '[[7, 10]]', '[17]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '2', '4', '[10, 11]', '[10, 8]', '18', '[[10, 11]]', "['BJ']", "[['S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '0', '4', '[6, 9]', '[10, 3, 8]', '21', '[[6, 9]]', '[15]', "[['R']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '1', '4', '[3, 10]', '[10, 10]', '20', '[[3, 10, 5]]', '[18]', "[['H', 'S']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '2', '4', '[10, 10]', '[10, 10]', '20', '[[10, 10]]', '[20]', "[['S']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '1', '3', '[4, 10]', '[9, 11]', '20', '[[4, 10, 10]]', '[24]', "[['H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '1', '2', '[2, 5]', '[6, 8, 2, 8]', '24', '[[2, 5, 11]]', '[18]', "[['H', 'S']]", '1', '1') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '1', '4', '[5, 2]', '[10, 7]', '17', '[[5, 2, 2, 2, 2, 2, 3]]', '[18]', "[['H', 'H', 'H', 'H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '2', '0', '[11, 5]', '[3, 7, 10]', '20', '[[11, 5, 10]]', '[16]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '4', '2', '[11, 9]', '[6, 10, 9]', '25', '[[11, 9]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '3', '2', '[5, 7]', '[7, 5, 10]', '22', '[[5, 7, 10]]', '[22]', "[['H']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '0', '3', '[8, 2]', '[9, 11]', '20', '[[8, 2, 10]]', '[20]', "[['D']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '1', '4', '[11, 5]', '[10, 10]', '20', '[[11, 5, 10, 5]]', '[21]', "[['H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '0', '4', '[10, 10]', '[10, 10]', '20', '[[10, 10]]', '[20]', "[['S']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '2', '4', '[11, 10]', '[10, 6, 2]', '18', '[[11, 10]]', "['BJ']", "[['S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '0', '4', '[11, 7]', '[10, 10]', '20', '[[11, 7, 2]]', '[20]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '3', '4', '[6, 10]', '[10, 10]', '20', '[[6, 10]]', '[16]', "[['R']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '4', '2', '[6, 2]', '[6, 10, 7]', '23', '[[6, 2, 5]]', '[13]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '3', '3', '[11, 8]', '[8, 9]', '17', '[[11, 8]]', '[19]', "[['S']]", '1', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '4', '0', '[2, 2]', '[3, 9, 3, 5]', '20', '[[2, 6, 7], [2, 10, 11]]', '[15, 13]', "[['P', 'H', 'S'], ['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '1', '3', '[8, 10]', '[8, 7, 6]', '21', '[[8, 10]]', '[18]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '4', '[3, 9]', '[11, 11, 10, 10]', '22', '[[3, 9, 3, 8]]', '[23]', "[['N', 'H', 'H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '1', '4', '[5, 10]', '[10, 7]', '17', '[[5, 10]]', '[15]', "[['R']]", '3', '3') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '1', '2', '[9, 10]', '[7, 10]', '17', '[[9, 10]]', '[19]', "[['S']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('2', '3', '4', '[9, 10]', '[10, 10]', '20', '[[9, 10]]', '[19]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '2', '1', '[11, 11]', '[5, 6, 6]', '17', '[[11, 4], [11, 9]]', '[15, 20]', "[['P'], []]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '4', '3', '[11, 5]', '[9, 10]', '19', '[[11, 5, 10, 9]]', '[25]', "[['H', 'H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '1', '3', '[4, 9]', '[9, 4, 10]', '23', '[[4, 9, 10]]', '[23]', "[['H']]", '3', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('1', '0', '4', '[7, 7]', '[11, 4, 3]', '18', '[[7, 7, 8]]', '[22]', "[['N', 'H']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '3', '3', '[5, 10]', '[8, 11]', '19', '[[5, 10, 11, 5]]', '[21]', "[['H', 'H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '4', '0', '[8, 5]', '[3, 10, 10]', '23', '[[8, 5]]', '[13]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '4', '4', '[10, 10]', '[10, 10]', '20', '[[10, 10]]', '[20]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '4', '0', '[10, 2]', '[2, 7, 5, 10]', '24', '[[10, 2, 4]]', '[16]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '4', '3', '[3, 5]', '[8, 5, 7]', '20', '[[3, 5, 9]]', '[17]', "[['H', 'S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('3', '4', '3', '[10, 11]', '[8, 10]', '18', '[[10, 11]]', "['BJ']", "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '4', '1', '[10, 8]', '[4, 2, 5, 6]', '17', '[[10, 8]]', '[18]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('0', '0', '2', '[6, 10]', '[6, 11, 5, 4, 4]', '20', '[[6, 10]]', '[16]', "[['S']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
# Warning: Condition ('4', '2', '4', '[8, 3]', '[10, 5, 11, 4]', '20', '[[8, 3, 2]]', '[13]', "[['D']]", '2', '2') not found in CPT for node win. Returning uniform distribution.
